# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import pathlib
from debater_python_api.api.debater_api import DebaterApi

# %%
#%run ../milestone2/milestone2.ipynb

# %% [markdown]
# ### 1. Load the API key and create a term wikifier client

# %%
apikey_path = pathlib.Path("../APIkey.txt")
api_key = apikey_path.read_text().strip()

# %%
debater_api = DebaterApi(apikey=api_key)

# %%
term_wikifier_client = debater_api.get_term_wikifier_client()

# %% [markdown]
#  ### 2. Reload the dataframe

# %%
df_merge = pd.read_csv("df_merge.csv")
df_merge.head()
# Out:
#      kp                                      sentence_text  match_score  \
# 0  none     The patient is a 1-year-old male with a his...          0.0
# 1  none    At the time of discharge, the patient had im...          0.0
# 2  none    CO2 insufflation was done to a maximum press...          0.0
# 3  none    Intrauterine pregnancy of 39 weeks, Herpes s...          0.0
# 4  none    L1 laminotomy, microdissection, retrieval of...          0.0
#
#    comment_id  sentence_id  sents_in_comment  span_start  span_end  \
# 0        1220            0                 1           0       157
# 1         577            0                 1           0        53
# 2        1591            0                 1           0       121
# 3        1302            0                 1           0       257
# 4        1100            0                 1           0       161
#
#    num_tokens  argument_quality    id  id_description  \
# 0          26          0.650918  1220            1114
# 1           9          0.442226   577             595
# 2          22          0.492457  1591            1304
# 3          34          0.630517  1302            1160
# 4          20          0.588591  1100            1036
#
#       medical_specialty_new
# 0     Pediatrics - Neonatal
# 1          General Medicine
# 2          Gastroenterology
# 3   Obstetrics / Gynecology
# 4              Neurosurgery

# %% [markdown]
# ### 3. Define a function that uses the term wikifier to map from a medical transcription in the dataset to a set of mentions in Wikipedia

# %%
#Gives a list of terms (in wikipedia) associated with each of the texts supplied
def get_sentence_to_mentions(sentences_texts):
    mentions_list = term_wikifier_client.run(sentences_texts)
    sentence_to_mentions = {}

    for sentence_text, mentions in zip(sentences_texts, mentions_list):
        sentence_to_mentions[sentence_text] = set([
            mention["concept"]["title"]
            for mention in mentions
        ])
    
    return sentence_to_mentions

# %%
#df_merge["kp"].unique()

# %%
#df_merge["sentence_text"][df_merge["kp"] == ' No evidence of polyps or malignancy.']

# %%
#stm = get_sentence_to_mentions(
#    df_merge["sentence_text"][df_merge["kp"] == ' No evidence of polyps or malignancy.'].values)

# %%
#stm

# %% [markdown]
# ### 4. Use this function to tally the references in wikipedia for each key point from the KPA

# %%
from collections import Counter

terms = {}

for kp in set(df_merge["kp"].values):
    sentence_to_mentions = get_sentence_to_mentions(
        df_merge["sentence_text"][df_merge["kp"] == kp].values
    )
    
    all_mentions = [
        mention
        for sentence in sentence_to_mentions
        for mention in sentence_to_mentions[sentence]
    ]
    
    term_count = dict(Counter(all_mentions))
    
    if "History" in term_count.keys():
        term_count.pop("History")
   
    terms[kp] = term_count
# Out:
# TermWikifierClient: 100%|█████████████████████████| 5/5 [00:00<00:00, 11.32it/s]
# TermWikifierClient: 100%|███████████████████████| 10/10 [00:00<00:00, 10.05it/s]
# TermWikifierClient: 100%|█████████████████████████| 7/7 [00:00<00:00,  7.07it/s]
# TermWikifierClient: 100%|█████████████████████████| 9/9 [00:01<00:00,  8.97it/s]
# TermWikifierClient: 100%|█████████████████████| 106/106 [00:01<00:00, 82.69it/s]
# TermWikifierClient: 100%|█████████████████████████| 2/2 [00:00<00:00,  2.89it/s]
# TermWikifierClient: 100%|███████████████████████| 14/14 [00:01<00:00, 12.63it/s]
# TermWikifierClient: 100%|████████████████████| 342/342 [00:01<00:00, 182.02it/s]
# TermWikifierClient: 100%|█████████████████████████| 8/8 [00:00<00:00, 22.58it/s]
# TermWikifierClient: 100%|███████████████████████| 44/44 [00:01<00:00, 36.49it/s]
# TermWikifierClient: 100%|█████████████████████████| 9/9 [00:00<00:00, 11.23it/s]
# TermWikifierClient: 100%|█████████████████████████| 7/7 [00:00<00:00,  7.24it/s]
# TermWikifierClient: 100%|███████████████████████| 75/75 [00:01<00:00, 57.50it/s]
# TermWikifierClient: 100%|███████████████████████| 19/19 [00:00<00:00, 24.39it/s]
# TermWikifierClient: 100%|█████████████████████| 128/128 [00:01<00:00, 99.28it/s]
# TermWikifierClient: 100%|███████████████████████| 31/31 [00:00<00:00, 42.13it/s]
# TermWikifierClient: 100%|███████████████████████| 26/26 [00:00<00:00, 27.19it/s]
# TermWikifierClient: 100%|███████████████████████| 12/12 [00:00<00:00, 13.26it/s]
# TermWikifierClient: 100%|█████████████████████████| 4/4 [00:00<00:00,  4.10it/s]
# TermWikifierClient: 100%|█████████████████████████| 4/4 [00:00<00:00,  4.07it/s]
# TermWikifierClient: 100%|███████████████████████| 30/30 [00:01<00:00, 26.26it/s]

# %%
#Dump the terms dictionary to a json file
import json

with open("terms.json", "w") as fp:
    json.dump(terms, fp)

# %% [markdown]
# ### 5. Display the analysis for one diagnosis

# %%
df_check = pd.DataFrame(
    list(terms[" Palpitations, possibly related to anxiety"].items()),
    columns = ["Term", "Count"],
).sort_values(by="Count", ascending=False)

df_check.head(10)
# Out:
#                    Term  Count
# 0               Anxiety      3
# 8               Patient      2
# 11                 Fair      1
# 19             Hospital      1
# 18  Work-up (chemistry)      1
# 17            Anhedonia      1
# 16                Mouth      1
# 15   Situational ethics      1
# 14              Amnesia      1
# 13          Probability      1

# %% [markdown]
# ### 6. Remove rows with key point 'none' and compare the size of key point clusters

# %%
df_clean = df_merge[df_merge["kp"] != "none"]
#df_clean["kp"].value_counts()
df_clean.head()
# Out:
#                                        kp  \
# 342   Possible inflammatory bowel disease
# 343   Possible inflammatory bowel disease
# 344   Possible inflammatory bowel disease
# 345   Possible inflammatory bowel disease
# 346   Possible inflammatory bowel disease
#
#                                          sentence_text  match_score  \
# 342                Possible inflammatory bowel disease     1.000000
# 343   Comprehensive Evaluation - Diabetes, hyperten...     0.999734
# 344   Gastroesophageal reflux disease, hiatal herni...     0.999734
# 345   Patient with a diagnosis of pancreatitis, dev...     0.999733
# 346   Colonoscopy due to rectal bleeding, constipat...     0.999732
#
#      comment_id  sentence_id  sents_in_comment  span_start  span_end  \
# 342        1924            0                 1           0        36
# 343        3083            0                 1           0        91
# 344        1264            0                 1           0        69
# 345         777            0                 1           0       127
# 346         812            0                 1           0       105
#
#      num_tokens  argument_quality    id  id_description medical_specialty_new
# 342           4          0.617659  1924            1470      Gastroenterology
# 343           9          0.620602  3083            2235      General Medicine
# 344           7          0.726280  1264            1139      Gastroenterology
# 345          18          0.609229   777             809            Nephrology
# 346          14          0.656341   812             846      Gastroenterology

# %% [markdown]
# ### 7. Visualize the relative frequency of key points grouped by medilal speciality, the distribution of medical specialities for each key point, and the top 10 terms from wikipedia for each key point

# %%
import seaborn as sns

#Frequency of key points grouped by medical speciality
sns.set(rc = { "figure.figsize": (20, 14) }, font_scale=2)
sns.countplot(
    y="medical_specialty_new",
    data=df_clean,
    order=df_clean["medical_specialty_new"].value_counts().index
);

# %%
#Distribution of medical specialities for each key point
sns.set(font_scale=2)
g = sns.FacetGrid(df_clean, col="kp", col_wrap=2, height=10)
g.map_dataframe(sns.countplot,
    y="medical_specialty_new",
    data=df_clean,
    order=df_clean["medical_specialty_new"].value_counts().index
);

# %%
len(terms)
# Out:
# 21

# %%
#Top 10 wikipedia terms for each key point
fig, ax = plt.subplots(11, 2, figsize=(20,70))
count = 0
for kp in terms:
    i = count//ax.shape[1]
    j = count-i*ax.shape[1]
    #print(i,j)
    dc = dict(sorted(terms[kp].items(), key= lambda x: x[1], reverse=True)[:10])
    dc_df = pd.DataFrame({"term":dc.keys(), "frequency":dc.values()})
    #display(dc_df)
    sns.barplot(data=dc_df, ax=ax[i,j], x="term",y="frequency").set(title=kp)
    ax[i,j].set_xticklabels(ax[i,j].get_xticklabels(), rotation=45, horizontalalignment='right')
    count += 1

plt.subplots_adjust(wspace=0.4,hspace=5)

# %% [markdown]
# ### 8. Save the data frame to a file

# %%
df_clean.to_csv("df_clean.csv", index=False)
